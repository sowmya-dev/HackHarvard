# %% [markdown]
# speaker labels with single voice

# %%
import requests

endpoint = "https://api.assemblyai.com/v2/transcript"

json = {
  "audio_url": "https://s3-us-west-2.amazonaws.com/blog.assemblyai.com/audio/8-7-2018-post/7510.mp3",
  "speaker_labels": True
}

headers = {
    "authorization": "37448d47889248d7bf029945fc7f60de",
    "content-type": "application/json"
}

response = requests.post(endpoint, json=json, headers=headers)

print(response.json())
# Out:
# {'id': 'v33j1heyn-c91d-4e0b-9df5-110304946257', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'queued', 'audio_url': 'https://s3-us-west-2.amazonaws.com/blog.assemblyai.com/audio/8-7-2018-post/7510.mp3', 'text': None, 'words': None, 'utterances': None, 'confidence': None, 'audio_duration': None, 'punctuate': True, 'format_text': True, 'dual_channel': None, 'webhook_url': None, 'webhook_status_code': None, 'speed_boost': False, 'auto_highlights_result': None, 'auto_highlights': False, 'audio_start_from': None, 'audio_end_at': None, 'word_boost': [], 'boost_param': None, 'filter_profanity': False, 'redact_pii': False, 'redact_pii_audio': False, 'redact_pii_audio_quality': None, 'redact_pii_policies': None, 'redact_pii_sub': None, 'speaker_labels': True, 'content_safety': False, 'iab_categories': False, 'content_safety_labels': {}, 'iab_categories_result': {}}

# %%
import requests

endpoint = "https://api.assemblyai.com/v2/transcript/v33j1heyn-c91d-4e0b-9df5-110304946257"

headers = {
    "authorization": "37448d47889248d7bf029945fc7f60de",
}

response = requests.get(endpoint, headers=headers)

print(response.json())
# Out:
# {'id': 'v33j1heyn-c91d-4e0b-9df5-110304946257', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'completed', 'audio_url': 'https://s3-us-west-2.amazonaws.com/blog.assemblyai.com/audio/8-7-2018-post/7510.mp3', 'text': 'You know, demons on TV like that. And and for people to expose themselves to being rejected on TV. Or, you know, he Mi humiliated by Fear Factor or, you know.', 'words': [{'text': 'You', 'confidence': 1.0, 'speaker': 'A', 'end': 450, 'start': 0}, {'text': 'know,', 'confidence': 0.99, 'speaker': 'A', 'end': 690, 'start': 460}, {'text': 'demons', 'confidence': 0.96, 'speaker': 'A', 'end': 1350, 'start': 700}, {'text': 'on', 'confidence': 0.95, 'speaker': 'A', 'end': 1560, 'start': 1350}, {'text': 'TV', 'confidence': 0.98, 'speaker': 'A', 'end': 1740, 'start': 1570}, {'text': 'like', 'confidence': 1.0, 'speaker': 'A', 'end': 2130, 'start': 1800}, {'text': 'that.', 'confidence': 1.0, 'speaker': 'A', 'end': 2340, 'start': 2140}, {'te
# ...

# %% [markdown]
# speaker labels

# %%
import requests

endpoint = "https://api.assemblyai.com/v2/transcript"

json = {
  "audio_url": "https://nicetalkingwithyou.com/wp-content/uploads/2018/07/003NTWY_U1_CL.mp3",
  "speaker_labels": True
}

headers = {
    "authorization": "37448d47889248d7bf029945fc7f60de",
    "content-type": "application/json"
}

response = requests.post(endpoint, json=json, headers=headers)

print(response.json())
# Out:
# {'id': 'v33mcs0yk-30d0-4862-b439-efe117b5c137', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'queued', 'audio_url': 'https://nicetalkingwithyou.com/wp-content/uploads/2018/07/003NTWY_U1_CL.mp3', 'text': None, 'words': None, 'utterances': None, 'confidence': None, 'audio_duration': None, 'punctuate': True, 'format_text': True, 'dual_channel': None, 'webhook_url': None, 'webhook_status_code': None, 'speed_boost': False, 'auto_highlights_result': None, 'auto_highlights': False, 'audio_start_from': None, 'audio_end_at': None, 'word_boost': [], 'boost_param': None, 'filter_profanity': False, 'redact_pii': False, 'redact_pii_audio': False, 'redact_pii_audio_quality': None, 'redact_pii_policies': None, 'redact_pii_sub': None, 'speaker_labels': True, 'content_safety': False, 'iab_categories': False, 'content_safety_labels': {}, 'iab_categories_result': {}}

# %%
import requests

endpoint = "https://api.assemblyai.com/v2/transcript/v33mcs0yk-30d0-4862-b439-efe117b5c137"

headers = {
    "authorization": "37448d47889248d7bf029945fc7f60de",
}

response = requests.get(endpoint, headers=headers)

print(response.json())
# Out:
# {'id': 'v33mcs0yk-30d0-4862-b439-efe117b5c137', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'completed', 'audio_url': 'https://nicetalkingwithyou.com/wp-content/uploads/2018/07/003NTWY_U1_CL.mp3', 'text': "Unit one. Page twelve. Conversation listening. Conversation one. So. Nice to meet you. You too. Where are you from? From? I'm from here. Well, near here. I live just outside the city and the suburbs with my family. The suburbs. That's nice. And do you have a hobby? Who has time for hobbies? I guess I like studying. Studying? Yeah, well, that's what I do most of the time. I want to work, get a good job later. So studying is what I'm into right now. Well, good luck with that. Thanks. How about you? Me? I like to draw on design stuff. Conversation, too. So do you live by yourself or with your family? I live alone. I got an apartment in the center of the city downtown. Yeah, right. It's not so convenient, but it's okay. I miss my family som
# ...

# %% [markdown]
# auto detecting main keywords and phrases

# %%
import requests

endpoint = "https://api.assemblyai.com/v2/transcript"

json = {
  "audio_url": "https://nicetalkingwithyou.com/wp-content/uploads/2018/07/003NTWY_U1_CL.mp3",
  "auto_highlights": True
}

headers = {
    "authorization": "37448d47889248d7bf029945fc7f60de",
    "content-type": "application/json"
}

response = requests.post(endpoint, json=json, headers=headers)

print(response.json())
# Out:
# {'id': 'v33vfi8ip-8187-431f-b676-7782b5962908', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'queued', 'audio_url': 'https://nicetalkingwithyou.com/wp-content/uploads/2018/07/003NTWY_U1_CL.mp3', 'text': None, 'words': None, 'utterances': None, 'confidence': None, 'audio_duration': None, 'punctuate': True, 'format_text': True, 'dual_channel': None, 'webhook_url': None, 'webhook_status_code': None, 'speed_boost': False, 'auto_highlights_result': None, 'auto_highlights': True, 'audio_start_from': None, 'audio_end_at': None, 'word_boost': [], 'boost_param': None, 'filter_profanity': False, 'redact_pii': False, 'redact_pii_audio': False, 'redact_pii_audio_quality': None, 'redact_pii_policies': None, 'redact_pii_sub': None, 'speaker_labels': False, 'content_safety': False, 'iab_categories': False, 'content_safety_labels': {}, 'iab_categories_result': {}}

# %%
import requests

endpoint = "https://api.assemblyai.com/v2/transcript/v33vfi8ip-8187-431f-b676-7782b5962908"

headers = {
    "authorization": "37448d47889248d7bf029945fc7f60de",
}

response = requests.get(endpoint, headers=headers)

print(response.json())
# Out:
# {'id': 'v33vfi8ip-8187-431f-b676-7782b5962908', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'completed', 'audio_url': 'https://nicetalkingwithyou.com/wp-content/uploads/2018/07/003NTWY_U1_CL.mp3', 'text': "Unit one. Page twelve. Conversation listening. Conversation one. So nice to meet you. You too. Where are you from? From? I'm from here. Well, near here. I live just outside the city and the suburbs with my family. The suburbs. That's nice. And do you have a hobby? Who has time for hobbies? I guess I like studying. Studying? Yeah, well, that's what I do most of the time. I want to work, get a good job later. So studying is what I'm into right now. Well, good luck with that. Thanks. How about you? Me? I like to draw on design stuff. Conversation, too. So do you live by yourself or with your family? I live alone. I got an apartment in the center of the city downtown. Yeah, right. It's not so convenient, but it's okay. I miss my family some
# ...

# %% [markdown]
# topic detection

# %%
import requests

endpoint = "https://api.assemblyai.com/v2/transcript"

json = {
  "audio_url": "https://s3-us-west-2.amazonaws.com/blog.assemblyai.com/audio/8-7-2018-post/7510.mp3",
  "iab_categories":True
}

headers = {
    "authorization": "37448d47889248d7bf029945fc7f60de",
    "content-type": "application/json"
}

response = requests.post(endpoint, json=json, headers=headers)

print(response.json())
# Out:
# {'id': 'v3px0t86r-5b4c-4f39-b8f3-61e03e05f5e3', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'queued', 'audio_url': 'https://s3-us-west-2.amazonaws.com/blog.assemblyai.com/audio/8-7-2018-post/7510.mp3', 'text': None, 'words': None, 'utterances': None, 'confidence': None, 'audio_duration': None, 'punctuate': True, 'format_text': True, 'dual_channel': None, 'webhook_url': None, 'webhook_status_code': None, 'speed_boost': False, 'auto_highlights_result': None, 'auto_highlights': False, 'audio_start_from': None, 'audio_end_at': None, 'word_boost': [], 'boost_param': None, 'filter_profanity': False, 'redact_pii': False, 'redact_pii_audio': False, 'redact_pii_audio_quality': None, 'redact_pii_policies': None, 'redact_pii_sub': None, 'speaker_labels': False, 'content_safety': False, 'iab_categories': True, 'content_safety_labels': {}, 'iab_categories_result': {}}

# %%
import requests

endpoint = "https://api.assemblyai.com/v2/transcript/v3px0t86r-5b4c-4f39-b8f3-61e03e05f5e3"

headers = {
    "authorization": "37448d47889248d7bf029945fc7f60de",
}

response = requests.get(endpoint, headers=headers)

print(response.json())
# Out:
# {'id': 'v3px0t86r-5b4c-4f39-b8f3-61e03e05f5e3', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'completed', 'audio_url': 'https://s3-us-west-2.amazonaws.com/blog.assemblyai.com/audio/8-7-2018-post/7510.mp3', 'text': 'You know, demons on TV like that. And and for people to expose themselves to being rejected on TV. Or you know, her Mi humiliated by fear Factor or, you know.', 'words': [{'text': 'You', 'confidence': 0.96, 'end': 450, 'start': 0}, {'text': 'know,', 'confidence': 0.93, 'end': 690, 'start': 460}, {'text': 'demons', 'confidence': 0.95, 'end': 1350, 'start': 700}, {'text': 'on', 'confidence': 0.95, 'end': 1560, 'start': 1350}, {'text': 'TV', 'confidence': 0.94, 'end': 1740, 'start': 1570}, {'text': 'like', 'confidence': 1.0, 'end': 2130, 'start': 1800}, {'text': 'that.', 'confidence': 0.95, 'end': 2340, 'start': 2140}, {'text': 'And', 'confidence': 0.97, 'end': 2580, 'start': 2350}, {'text': 'and', 'confidence': 1.0, 'end': 3090, '
# ...

# %% [markdown]
# content safety detection

# %%
import requests

endpoint = "https://api.assemblyai.com/v2/transcript"

json = {
  "audio_url": "https://nicetalkingwithyou.com/wp-content/uploads/2018/07/003NTWY_U1_CL.mp3",
  "auto_highlights": True,"content_safety":True
}

headers = {
    "authorization": "37448d47889248d7bf029945fc7f60de",
    "content-type": "application/json"
}

response = requests.post(endpoint, json=json, headers=headers)

print(response.json())
# Out:
# {'id': 'v35n973mp-fd4b-408e-ba8e-7f8ee631928f', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'queued', 'audio_url': 'https://nicetalkingwithyou.com/wp-content/uploads/2018/07/003NTWY_U1_CL.mp3', 'text': None, 'words': None, 'utterances': None, 'confidence': None, 'audio_duration': None, 'punctuate': True, 'format_text': True, 'dual_channel': None, 'webhook_url': None, 'webhook_status_code': None, 'speed_boost': False, 'auto_highlights_result': None, 'auto_highlights': True, 'audio_start_from': None, 'audio_end_at': None, 'word_boost': [], 'boost_param': None, 'filter_profanity': False, 'redact_pii': False, 'redact_pii_audio': False, 'redact_pii_audio_quality': None, 'redact_pii_policies': None, 'redact_pii_sub': None, 'speaker_labels': False, 'content_safety': True, 'iab_categories': False, 'content_safety_labels': {}, 'iab_categories_result': {}}

# %%
import requests

endpoint = "https://api.assemblyai.com/v2/transcript/v35n973mp-fd4b-408e-ba8e-7f8ee631928f"
headers = {
    "authorization": "37448d47889248d7bf029945fc7f60de",
}

response = requests.get(endpoint, headers=headers)

print(response.json())
# Out:
# {'id': 'v35n973mp-fd4b-408e-ba8e-7f8ee631928f', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'completed', 'audio_url': 'https://nicetalkingwithyou.com/wp-content/uploads/2018/07/003NTWY_U1_CL.mp3', 'text': "Unit one. Page twelve. Conversation listening. Conversation one. So nice to meet you. You too. Where are you from? From? I'm from here. Well, near here. I live just outside the city and the suburbs with my family. The suburbs. That's nice. And do you have a hobby? Who has time for hobbies? I guess I like studying. Studying? Yeah, well, that's what I do most of the time. I want to work, get a good job later. So studying is what I'm into right now. Well, good luck with that. Thanks. How about you? Me? I like to draw on design stuff. Conversation, too. So do you live by yourself or with your family? I live alone. I got an apartment in the center of the city downtown. Yeah, right. It's not so convenient, but it's okay. I miss my family some
# ...
